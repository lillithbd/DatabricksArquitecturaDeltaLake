# %%
#Creamos la carpeta raíz del DELTA LAKE
# %fs mkdirs dbfs:///FileStore/curso_databricks/deltalake

# %%
#Creamos la carpeta "bronze"
# %fs mkdirs dbfs:///FileStore/curso_databricks/deltalake/bronze
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res31: Boolean = true
# </div>

# %%
#Simulamos una carpeta para los datos crudos
# %fs mkdirs dbfs:///FileStore/curso_databricks/deltalake/bronze/raw_data

# %%
#Creamos la carpeta "silver"
# %fs mkdirs dbfs:///FileStore/curso_databrick/deltalake/silver
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res36: Boolean = true
# </div>

# %%
#Simulamos una carpeta para los datos limpiados
# %fs mkdirs dbfs:///FileStore/curso_databrick/deltalake/silver/cleaning_data

# %%
#Creamos la carpeta "gold"
# %fs mkdirs dbfs:///FileStore/curso_databrick/deltalake/gold
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res42: Boolean = true
# </div>

# %%
#Simulamos una carpeta para los datos procesados
# %fs mkdirs dbfs:///FileStore/curso_databrick/deltalake/gold/final_data
